# %% [markdown]
# # Linux Master Quiz - 입문
# **서버 기본 조작** | 15문제
#
# 셀에 정답을 입력하고 실행(Shift+Enter)하면 즉시 채점됩니다.
#
# - 문자열로 입력: `answer = "your command here"`
# - 힌트가 필요하면 `quiz.hint()`를 실행하세요
# - 참고자료: [guide_beginner.md](guide_beginner.md)

# %%
from engine import Quiz
quiz = Quiz("q1")
print("\u2705 채점 엔진 준비 완료! (입문 - 서버 기본 조작)")

# %%
# Q1. 현재 내가 어는 폴더에 있는지 확인하려면?
answer = ""
quiz.check(1, answer)
# quiz.hint()

# %%
# Q2. 홈 디렉토리로 이동하려면?
answer = ""
quiz.check(2, answer)
# quiz.hint()

# %%
# Q3. 한 단계 상위 폴더로 이동하려면?
answer = ""
quiz.check(3, answer)
# quiz.hint()

# %%
# Q4. /home/user/data 폴더로 이동하려면?
answer = ""
quiz.check(4, answer)
# quiz.hint()

# %%
# Q5. 현재 폴더의 파일 목록을 보려면?
answer = ""
quiz.check(5, answer)
# quiz.hint()

# %%
# Q6. file.txt 내용을 터미널에 출력하려면?
answer = ""
quiz.check(6, answer)
# quiz.hint()

# %%
# Q7. 긴 파일을 스크롤하면서 보려면?
answer = ""
quiz.check(7, answer)
# quiz.hint()

# %%
# Q8. vim으로 config.yaml을 열려면?
answer = ""
quiz.check(8, answer)
# quiz.hint()

# %%
# Q9. vim에서 편집(입력) 모드로 들어가려면 어떤 키를 누르나?
answer = ""
quiz.check(9, answer)
# quiz.hint()

# %%
# Q10. vim에서 저장하고 나가려면? (명령 모드에서)
answer = ""
quiz.check(10, answer)
# quiz.hint()

# %%
# Q11. vim에서 저장하지 않고 강제로 나가려면?
answer = ""
quiz.check(11, answer)
# quiz.hint()

# %%
# Q12. 터미널 화면을 깨끗이 지우려면?
answer = ""
quiz.check(12, answer)
# quiz.hint()

# %%
# Q13. 내가 누굨로 로그인했는지 확인하려면?
answer = ""
quiz.check(13, answer)
# quiz.hint()

# %%
# Q14. ls 명령어의 매뉴얼을 보려면?
answer = ""
quiz.check(14, answer)
# quiz.hint()

# %%
# Q15. 서버 접속(터미널)을 종료하려면?
answer = ""
quiz.check(15, answer)
# quiz.hint()

# %%
quiz.summary()

# %% [markdown]
# ---
# ## 다음 단계
# 1. 결과를 확인하고 틀린 문제를 복습하세요
# 2. 보강자료 `r1.md`를 읽어보세요 (퀴즈 결과 기반으로 생성)
# 3. 준비되면 **[q2.ipynb](q2.ipynb)** (초급 - 파일/폴더 다루기)로 진행하세요
