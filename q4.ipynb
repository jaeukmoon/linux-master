# %% [markdown]
# # Linux Master Quiz - 고급
# **네트워크, 압축, 실전 조합** | 15문제
#
# 셀에 정답을 입력하고 실행(Shift+Enter)하면 즉시 채점됩니다.
#
# - 문자열로 입력: `answer = "your command here"`
# - 힌트가 필요하면 `quiz.hint()`를 실행하세요
# - 참고자료: [guide_advanced.md](guide_advanced.md)

# %%
from engine import Quiz
quiz = Quiz("q4")
print("\u2705 채점 엔진 준비 완료! (고급 - 네트워크, 압축, 실전 조합)")

# %%
# Q1. 터미널을 닫아도 학습이 계속되도록 + 로그르 train.log에 저장하려면?
answer = ""
quiz.check(1, answer)
# quiz.hint()

# %%
# Q2. GPU 0번과 1번만 사용해서 train.py를 실행하려면?
answer = ""
quiz.check(2, answer)
# quiz.hint()

# %%
# Q3. file.txt를 user@server의 /home/user/로 복사하려면?
answer = ""
quiz.check(3, answer)
# quiz.hint()

# %%
# Q4. my_folder/를 archive.tar.gz로 압축하려면?
answer = ""
quiz.check(4, answer)
# quiz.hint()

# %%
# Q5. archive.tar.gz를 압축 풀려면?
answer = ""
quiz.check(5, answer)
# quiz.hint()

# %%
# Q6. 디스크 전체 사용량을 보기 좋은 단위로 확인하려면?
answer = ""
quiz.check(6, answer)
# quiz.hint()

# %%
# Q7. 현재 폴더의 각 항목 크기를 보려면?
answer = ""
quiz.check(7, answer)
# quiz.hint()

# %%
# Q8. log.txt에서 ERROR가 포함된 줄이 몇 개인지 세려면?
answer = ""
quiz.check(8, answer)
# quiz.hint()

# %%
# Q9. 현재 폴더에 .json 파일이 몇 개 있는지 세려면?
answer = ""
quiz.check(9, answer)
# quiz.hint()

# %%
# Q10. ERROR만 뽁아서 errors.log 파일로 저장하려면?
answer = ""
quiz.check(10, answer)
# quiz.hint()

# %%
# Q11. 최근 100줄의 로그에서 WARNING만 찾으려면?
answer = ""
quiz.check(11, answer)
# quiz.hint()

# %%
# Q12. 폴더별 용량을 큰 순서대로 상위 10개만 보려면?
answer = ""
quiz.check(12, answer)
# quiz.hint()

# %%
# Q13. (복습) my_data/ 폴더 전체를 서버로 복사하려면?
answer = ""
quiz.check(13, answer)
# quiz.hint()

# %%
# Q14. (복습) archive.tar.gz를 /target/ 폴더에 풀려면?
answer = ""
quiz.check(14, answer)
# quiz.hint()

# %%
# Q15. (복습) .pyc 캐시 파일을 전부 찾아서 삭젖하려면?
answer = ""
quiz.check(15, answer)
# quiz.hint()

# %%
quiz.summary()

# %% [markdown]
# ---
# ## 축하합니다!
# 모든 레벨을 완료했습니다. 틀린 문제가 있다면 보강자료 `r4.md`를 확인하세요.
