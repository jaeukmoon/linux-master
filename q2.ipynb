# %% [markdown]
# # Linux Master Quiz - 초급
# **파일/폴더 다루기** | 15문제
#
# 셀에 정답을 입력하고 실행(Shift+Enter)하면 즉시 채점됩니다.
#
# - 문자열로 입력: `answer = "your command here"`
# - 힌트가 필요하면 `quiz.hint()`를 실행하세요
# - 참고자료: [guide_beginner.md](guide_beginner.md)

# %%
from engine import Quiz
quiz = Quiz("q2")
print("\u2705 채점 엔진 준비 완료! (초급 - 파일/폴더 다루기)")

# %%
# Q1. 현재 폴더의 파일 목록을 자세히 보려면?
answer = ""
quiz.check(1, answer)
# quiz.hint()

# %%
# Q2. 숨김 파일까지 포함해서 자세히 보려면?
answer = ""
quiz.check(2, answer)
# quiz.hint()

# %%
# Q3. 파일 크기를 MB/GB 단위로 자세히 보려면?
answer = ""
quiz.check(3, answer)
# quiz.hint()

# %%
# Q4. data/raw/2024 폴더를 한번에 만드려면? (중간 폴더가 없어도)
answer = ""
quiz.check(4, answer)
# quiz.hint()

# %%
# Q5. my_folder/ 전체를 backup_folder/로 복사하려면?
answer = ""
quiz.check(5, answer)
# quiz.hint()

# %%
# Q6. old.txt 이름을 new.txt로 바꾸려면?
answer = ""
quiz.check(6, answer)
# quiz.hint()

# %%
# Q7. my_folder/ 전체를 확인 없이 삭제하려면?
answer = ""
quiz.check(7, answer)
# quiz.hint()

# %%
# Q8. file.txt 내용을 줄번호와 함께 출력하려면?
answer = ""
quiz.check(8, answer)
# quiz.hint()

# %%
# Q9. file.txt의 처음 20줄만 보려면?
answer = ""
quiz.check(9, answer)
# quiz.hint()

# %%
# Q10. log.txt에 새로운 내용이 추가되는 걸 실시간으로 보려면?
answer = ""
quiz.check(10, answer)
# quiz.hint()

# %%
# Q11. file.txt의 줄 수를 세려면?
answer = ""
quiz.check(11, answer)
# quiz.hint()

# %%
# Q12. (복습) results/output/ 폴더를 한번에 만드려면?
answer = ""
quiz.check(12, answer)
# quiz.hint()

# %%
# Q13. (복습) src/ 폴더를 src_backup/으로 복사하려면?
answer = ""
quiz.check(13, answer)
# quiz.hint()

# %%
# Q14. (복습) train.log의 마지막 50줄만 보려면?
answer = ""
quiz.check(14, answer)
# quiz.hint()

# %%
# Q15. (복습) temp/ 폴더를 강제 삭제하려면?
answer = ""
quiz.check(15, answer)
# quiz.hint()

# %%
quiz.summary()

# %% [markdown]
# ---
# ## 다음 단계
# 1. 결과를 확인하고 틀린 문제를 복습하세요
# 2. 보강자료 `r2.md`를 읽어보세요 (퀴즈 결과 기반으로 생성)
# 3. 준비되면 **[q3.ipynb](q3.ipynb)** (중급 - 검색, 파이프, 권한, 프로세스)로 진행하세요
