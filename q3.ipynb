# %% [markdown]
# # Linux Master Quiz - 중급
# **검색, 파이프, 권한, 프로세스** | 15문제
#
# 셀에 정답을 입력하고 실행(Shift+Enter)하면 즉시 채점됩니다.
#
# - 문자열로 입력: `answer = "your command here"`
# - 힌트가 필요하면 `quiz.hint()`를 실행하세요
# - 참고자료: [guide_intermediate.md](guide_intermediate.md)

# %%
from engine import Quiz
quiz = Quiz("q3")
print("\u2705 채점 엔진 준비 완료! (중급 - 검색, 파이프, 권한, 프로세스)")

# %%
# Q1. log.txt에서 'error'가 포함픜 줄을 찾으려면?
answer = ""
quiz.check(1, answer)
# quiz.hint()

# %%
# Q2. log.txt에서 대소문자 구분 없이 'error'를 검색하려면?
answer = ""
quiz.check(2, answer)
# quiz.hint()

# %%
# Q3. 현재 폴더 아래 모든 파일에서 'import torch'를 검색하려면?
answer = ""
quiz.check(3, answer)
# quiz.hint()

# %%
# Q4. log.txt에서 'DEBUG'가 없는 줄만 보려면?
answer = ""
quiz.check(4, answer)
# quiz.hint()

# %%
# Q5. 현재 폴더 아래에서 .py 파일을 모두 찾으려면?
answer = ""
quiz.check(5, answer)
# quiz.hint()

# %%
# Q6. 100MB보다 큰 파일을 찾으려면?
answer = ""
quiz.check(6, answer)
# quiz.hint()

# %%
# Q7. 실행 중인 프로세스에서 python만 필터링하려면?
answer = ""
quiz.check(7, answer)
# quiz.hint()

# %%
# Q8. 'hello'를 output.txt에 저장(덮어쓰기)하려면?
answer = ""
quiz.check(8, answer)
# quiz.hint()

# %%
# Q9. 'world'를 output.txt 끝에 추가하려면?
answer = ""
quiz.check(9, answer)
# quiz.hint()

# %%
# Q10. script.sh에 실행 권한을 추가하려면?
answer = ""
quiz.check(10, answer)
# quiz.hint()

# %%
# Q11. PID 12345 프로세스를 강제 종료하려면?
answer = ""
quiz.check(11, answer)
# quiz.hint()

# %%
# Q12. python train.py의 출력과 에러를 모두 all.log에 저장하려면?
answer = ""
quiz.check(12, answer)
# quiz.hint()

# %%
# Q13. (복습) app.log에서 줄번호와 함께 'WARNING'을 검색하려면?
answer = ""
quiz.check(13, answer)
# quiz.hint()

# %%
# Q14. (복습) .log 파일을 찾아서 전부 삭제하려면?
answer = ""
quiz.check(14, answer)
# quiz.hint()

# %%
# Q15. (복습) script.sh를 소유자=rwx, 그룹=r-x, 기타=r-x로 설정하려면?
answer = ""
quiz.check(15, answer)
# quiz.hint()

# %%
quiz.summary()

# %% [markdown]
# ---
# ## 다음 단계
# 1. 결과를 확인하고 틀린 문제를 복습하세요
# 2. 보강자료 `r3.md`를 읽어보세요 (퀴즈 결과 기반으로 생성)
# 3. 준비되면 **[q4.ipynb](q4.ipynb)** (고급 - 네트워크, 압축, 실전 조합)로 진행하세요
